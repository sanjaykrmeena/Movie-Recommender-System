# %%
import numpy as np
import pandas as pd

# %%
movies=pd.read_csv('tmdb_5000_movies.csv')
credits=pd.read_csv('tmdb_5000_credits.csv')

# %%
movies=movies.merge(credits,on='title')
credits
# Out:
#      movie_id                                     title  \
# 0       19995                                    Avatar
# 1         285  Pirates of the Caribbean: At World's End
# 2      206647                                   Spectre
# 3       49026                     The Dark Knight Rises
# 4       49529                               John Carter
# ...       ...                                       ...
# 4808     9367                               El Mariachi
# 4809    72766                                 Newlyweds
# 4810   231617                 Signed, Sealed, Delivered
# 4811   126186                          Shanghai Calling
# 4812    25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 4808  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4809  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4810  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4811  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4812  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew Unnamed: 4 Unnamed: 5  \
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...        NaN        NaN
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...        NaN        NaN
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...        NaN        NaN
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...        NaN        NaN
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...        NaN        NaN
# ...                                                 ...        ...        ...
# 4808  [{"credit_id": "52fe44eec3a36847f80b280b", "de...        NaN        NaN
# 4809  [{"credit_id": "52fe487dc3a368484e0fb013", "de...        NaN        NaN
# 4810  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...        NaN        NaN
# 4811  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...        NaN        NaN
# 4812  [{"credit_id": "58ce021b9251415a390165d9", "de...        NaN        NaN
#
#      Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 1255  \
# 0           NaN        NaN        NaN        NaN  ...           NaN
# 1           NaN        NaN        NaN        NaN  ...           NaN
# 2           NaN        NaN        NaN        NaN  ...           NaN
# 3           NaN        NaN        NaN        NaN  ...           NaN
# 4           NaN        NaN        NaN        NaN  ...           NaN
# ...         ...        ...        ...        ...  ...           ...
# 4808        NaN        NaN        NaN        NaN  ...           NaN
# 4809        NaN        NaN        NaN        NaN  ...           NaN
# 4810        NaN        NaN        NaN        NaN  ...           NaN
# 4811        NaN        NaN        NaN        NaN  ...           NaN
# 4812        NaN        NaN        NaN        NaN  ...           NaN
#
#      Unnamed: 1256 Unnamed: 1257 Unnamed: 1258 Unnamed: 1259 Unnamed: 1260  \
# 0              NaN           NaN           NaN           NaN           NaN
# 1              NaN           NaN           NaN           NaN           NaN
# 2              NaN           NaN           NaN           NaN           NaN
# 3              NaN           NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...           ...
# 4808           NaN           NaN           NaN           NaN           NaN
# 4809           NaN           NaN           NaN           NaN           NaN
# 4810           NaN           NaN           NaN           NaN           NaN
# 4811           NaN           NaN           NaN           NaN           NaN
# 4812           NaN           NaN           NaN           NaN           NaN
#
#      Unnamed: 1261 Unnamed: 1262 Unnamed: 1263 Unnamed: 1264
# 0              NaN           NaN           NaN           NaN
# 1              NaN           NaN           NaN           NaN
# 2              NaN           NaN           NaN           NaN
# 3              NaN           NaN           NaN           NaN
# 4              NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...
# 4808           NaN           NaN           NaN           NaN
# 4809           NaN           NaN           NaN           NaN
# 4810           NaN           NaN           NaN           NaN
# 4811           NaN           NaN           NaN           NaN
# 4812           NaN           NaN           NaN           NaN
#
# [4813 rows x 1265 columns]

# %%
movies=movies[['movie_id','title','overview','genres','cast','crew','keywords']]

# %%
movies
# Out:
#      movie_id                                     title  \
# 0       19995                                    Avatar
# 1         285  Pirates of the Caribbean: At World's End
# 2      206647                                   Spectre
# 3       49026                     The Dark Knight Rises
# 4       49529                               John Carter
# ...       ...                                       ...
# 4984     9367                               El Mariachi
# 4985    72766                                 Newlyweds
# 4986   231617                 Signed, Sealed, Delivered
# 4987   126186                          Shanghai Calling
# 4988    25975                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 4984  El Mariachi just wants to play his guitar and ...
# 4985  A newlywed couple's honeymoon is upended by th...
# 4986  "Signed, Sealed, Delivered" introduces a dedic...
# 4987  When ambitious New York attorney Sam is sent t...
# 4988  Ever since the second grade when he first saw ...
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                 ...
# 4984  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4985  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4986  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4987                                                 []
# 4988                [{"id": 99, "name": "Documentary"}]
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 4984  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4985  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4986  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4987  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4988  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                    crew  \
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 4984  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
# 4985  [{"credit_id": "52fe487dc3a368484e0fb013", "de...
# 4986  [{"credit_id": "52fe4df3c3a36847f8275ecf", "de...
# 4987  [{"credit_id": "52fe4ad9c3a368484e16a36b", "de...
# 4988  [{"credit_id": "58ce021b9251415a390165d9", "de...
#
#                                                keywords
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4     [{"id": 818, "name": "based on novel"}, {"id":...
# ...                                                 ...
# 4984  [{"id": 5616, "name": "united states\u2013mexi...
# 4985                                                 []
# 4986  [{"id": 248, "name": "date"}, {"id": 699, "nam...
# 4987                                                 []
# 4988  [{"id": 1523, "name": "obsession"}, {"id": 224...
#
# [4989 rows x 7 columns]

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    0
# genres      0
# cast        0
# crew        0
# keywords    0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies['genres']
# Out:
# 0       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3       [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#                               ...
# 4984    [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4985    [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4986    [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4987                                                   []
# 4988                  [{"id": 99, "name": "Documentary"}]
# Name: genres, Length: 4982, dtype: object

# %%
import ast
def con(obj):
    ans=[]
    for i in ast.literal_eval(obj):
        ans.append(i['name'])
       
      
        
        
        
    return ans

# %%
movies['genres']=movies['genres'].apply(con)

# %%
movies['keywords']=movies['keywords'].apply(con)

# %%
movies.head()
# Out:
#   movie_id                                     title  \
# 0    19995                                    Avatar
# 1      285  Pirates of the Caribbean: At World's End
# 2   206647                                   Spectre
# 3    49026                     The Dark Knight Rises
# 4    49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
#                                             keywords
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
